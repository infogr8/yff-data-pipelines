# %%
from pathlib import Path

import pandas as pd
import petl as etl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
# %matplotlib inline

# %%
ROOT = Path('../..')

SRC_FILE = ROOT / 'data/raw/lfs_by_pcon.csv'

OUT_DIR = ROOT / 'data/processed/labour-market/'
OUT_DIR.mkdir(parents=True, exist_ok=True)

OUT_FILE = OUT_DIR / 'labour_market_by_pcon.csv'
PQ_FILE = OUT_DIR / 'labour_market_by_pcon.parquet'

# %% [markdown]
# Load the latest CSV. This is downloaded by the 'download-from-nomis-api.py' script.

# %%
data = etl.fromcsv(
  SRC_FILE
).convertall(
  lambda x: x.strip()
).convert(
  {
    'DATE': etl.dateparser('%Y-%m'),
    'OBS_VALUE': float
  }
).selecteq(
  'MEASURES_NAME', 'Variable'
).selectin(
  'GEOGRAPHY_TYPE', ['parliamentary constituencies 2010', 'Westminster Parliamentary Constituencies (July 2024)']
).cut(
  'DATE', 'DATE_NAME', 'GEOGRAPHY_CODE', 'GEOGRAPHY_NAME', 'VARIABLE_CODE', 'VARIABLE_NAME', 'OBS_VALUE', 'OBS_STATUS_NAME'
).rename({
  'DATE': 'date',
  'DATE_NAME': 'date_name',
  'GEOGRAPHY_CODE': 'geography_code',
  'GEOGRAPHY_NAME': 'geography_name',
  'VARIABLE_CODE': 'variable_code',
  'VARIABLE_NAME': 'variable_name',
  'OBS_VALUE': 'value',
  'OBS_STATUS_NAME': 'notes'
})

data
# Out:
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | date                      | date_name           | geography_code | geography_name             | variable_code | variable_name                         | value | notes          |
# +===========================+=====================+================+============================+===============+=======================================+=======+================+
# | datetime.date(2022, 3, 1) | 'Apr 2021-Mar 2022' | 'E14000530'    | 'Aldershot'                | '18'          | 'Economic activity rate - aged 16-64' |  81.1 | 'Normal Value' |
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2022, 3, 1) | 'Apr 2021-Mar 2022' | 'E14000531'    | 'Aldridge-Brownhills'      | '18'          | 'Economic activity rate - aged 16-64' |  86.6 | 'Normal Value' |
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2022, 3, 1) | 'Apr 2021-Mar 2022' | 'E14000532'    | 'Altrincham and Sale West' | '18'          | 'Economic activity rate - aged 16-64' |  76.5 | 'Normal Value' |
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2022, 3, 1) | 'Apr 2021-Mar 2022' | 'E14000533'    | 'Amber Valley'             | '18'          | 'Economic activity rate - aged 16-64' |  82.3 | 'Normal Value' |
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2022, 3, 1) | 'Apr 2021-Mar 2022' | 'E14000534'    | 'Arundel and South Downs'  | '18'          | 'Economic activity rate - aged 16-64' |  82.3 | 'Normal Value' |
# +---------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# ...

# %% [markdown]
# Save the file to CSV

# %%
data.tocsv(OUT_FILE)

# %% [markdown]
# Convert to pandas for further processing, and save Parquet file

# %%
frame = data.todataframe()
frame.date = pd.to_datetime(frame.date)
frame.to_parquet(PQ_FILE)

# %% [markdown]
# Check missing data

# %%
def visualise_coverage(data):
    counts = pd.DataFrame({
      'available': data.groupby(['date', 'variable_name']).value.count(),
      'total': data.groupby(['date', 'variable_name']).value.size()
    })
    coverage = pd.Series(
      counts.available / counts.total, name='coverage'
    ).reset_index().pivot(
      index='variable_name', columns='date', values='coverage'
    )
    plt.imshow(coverage, origin='lower', cmap='viridis', interpolation='nearest', aspect='auto')
    plt.grid(None)
    plt.ylabel('Measure')
    plt.yticks(ticks=range(len(coverage.index)), labels=coverage.index)
    plt.xticks(ticks=range(len(coverage.columns)), labels=coverage.columns.to_series().dt.strftime('%b %Y'), rotation=90, horizontalalignment='center')
    return coverage

frame.pipe(visualise_coverage)
# Out:
# date                                          2022-03-01  2022-06-01  \
# variable_name
# % of economically inactive student              0.905616    0.902496
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.861154    0.836973
# % who are economically inactive - aged 16-24    0.933697    0.921997
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.381435    0.358814
# Economic activity rate - aged 16-19             0.654446    0.661466
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.901716    0.878315
# Unemployment rate - aged 16+                    0.726989    0.691888
# Unemployment rate - aged 16-19                  0.051482    0.045242
# Unemployment rate - aged 16-24                  0.177067    0.136505
# Unemployment rate - aged 16-64                  0.705928    0.667707
# Unemployment rate - aged 20-24                  0.039002    0.032761
#
# date                                          2022-09-01  2022-12-01  \
# variable_name
# % of economically inactive student              0.884555    0.865055
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.822153    0.783931
# % who are economically inactive - aged 16-24    0.912637    0.886115
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.346334    0.342434
# Economic activity rate - aged 16-19             0.662246    0.608424
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.866615    0.839314
# Unemployment rate - aged 16+                    0.663807    0.627145
# Unemployment rate - aged 16-19                  0.037441    0.041342
# Unemployment rate - aged 16-24                  0.126365    0.113105
# Unemployment rate - aged 16-64                  0.640406    0.592044
# Unemployment rate - aged 20-24                  0.017941    0.019501
#
# date                                          2023-03-01  2023-06-01  \
# variable_name
# % of economically inactive student              0.821373    0.787051
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.740250    0.705148
# % who are economically inactive - aged 16-24    0.865835    0.829953
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.329953    0.287832
# Economic activity rate - aged 16-19             0.574103    0.532761
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.805772    0.776911
# Unemployment rate - aged 16+                    0.586583    0.566303
# Unemployment rate - aged 16-19                  0.036661    0.032761
# Unemployment rate - aged 16-24                  0.124025    0.113105
# Unemployment rate - aged 16-64                  0.559282    0.531981
# Unemployment rate - aged 20-24                  0.025741    0.021841
#
# date                                          2023-09-01  2023-12-01  \
# variable_name
# % of economically inactive student              0.735569    0.725429
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.649766    0.624805
# % who are economically inactive - aged 16-24    0.785491    0.770671
# % who are economically inactive - aged 16-64    0.985179    0.984399
# % who are economically inactive - aged 20-24    0.251950    0.222309
# Economic activity rate - aged 16-19             0.471919    0.445398
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.726209    0.693448
# Unemployment rate - aged 16+                    0.498440    0.474259
# Unemployment rate - aged 16-19                  0.024181    0.028861
# Unemployment rate - aged 16-24                  0.096724    0.080343
# Unemployment rate - aged 16-64                  0.468019    0.454758
# Unemployment rate - aged 20-24                  0.013261    0.014041
#
# date                                          2024-03-01  2024-06-01  \
# variable_name
# % of economically inactive student              0.726209    0.762871
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.635725    0.678627
# % who are economically inactive - aged 16-24    0.773011    0.799532
# % who are economically inactive - aged 16-64    0.982839    0.982839
# % who are economically inactive - aged 20-24    0.204368    0.241810
# Economic activity rate - aged 16-19             0.445398    0.460998
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.697348    0.712168
# Unemployment rate - aged 16+                    0.496880    0.481279
# Unemployment rate - aged 16-19                  0.027301    0.026521
# Unemployment rate - aged 16-24                  0.094384    0.094384
# Unemployment rate - aged 16-64                  0.471139    0.458658
# Unemployment rate - aged 20-24                  0.013261    0.018721
#
# date                                          2024-09-01  2024-12-01  \
# variable_name
# % of economically inactive student              0.793292    0.827613
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.724649    0.750390
# % who are economically inactive - aged 16-24    0.824493    0.866615
# % who are economically inactive - aged 16-64    0.985959    0.985179
# % who are economically inactive - aged 20-24    0.275351    0.307332
# Economic activity rate - aged 16-19             0.494540    0.542902
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.748830    0.772231
# Unemployment rate - aged 16+                    0.512480    0.568643
# Unemployment rate - aged 16-19                  0.031201    0.049142
# Unemployment rate - aged 16-24                  0.120125    0.146646
# Unemployment rate - aged 16-64                  0.490640    0.540562
# Unemployment rate - aged 20-24                  0.021841    0.026521
#
# date                                          2025-03-01
# variable_name
# % of economically inactive student              0.847894
# % who are economically inactive - aged 16+      0.985959
# % who are economically inactive - aged 16-19    0.773791
# % who are economically inactive - aged 16-24    0.891576
# % who are economically inactive - aged 16-64    0.985959
# % who are economically inactive - aged 20-24    0.342434
# Economic activity rate - aged 16-19             0.558502
# Economic activity rate - aged 16-64             0.985959
# Economic activity rate - aged 20-24             0.786271
# Unemployment rate - aged 16+                    0.586583
# Unemployment rate - aged 16-19                  0.060062
# Unemployment rate - aged 16-24                  0.166147
# Unemployment rate - aged 16-64                  0.570203
# Unemployment rate - aged 20-24                  0.035881

# %% [markdown]
# Get the most recently published data per area, to increase coverage

# %%
def get_latest_available(data):
  # Calculate dates
  failsafe_date = data.date.min() - pd.Timedelta("1 days")
  latest_date = data.date.max()
  # Subset the input data
  test_data = data.loc[:, ['geography_code', 'date', 'variable_name', 'value']]
  # Construct a failsafe (to be used in the event that there is no data available)
  # This will have the same index as the most recent values, which we use below...
  failsafe_data = test_data.loc[test_data.date == latest_date]
  failsafe_data.loc[:, ['date', 'value']] = (failsafe_date, -1)
  # Concatenate the test and failsafe_data
  test_data = pd.concat([ test_data, failsafe_data ]).sort_values('date', ascending=True)
  # Get the indexes for the non-zero values
  indexes = test_data.dropna(subset='value').groupby(['geography_code', 'variable_name'])['date'].idxmax()
  return data.loc[indexes]

latest_available = frame.pipe(get_latest_available)

# %%
latest = frame.loc[frame.date == frame.date.max()].groupby(['variable_name']).value
patched = latest_available.groupby(['variable_name']).value
coverage = pd.DataFrame({
  'latest coverage': latest.count() / latest.size() * 100,
  'patched coverage': patched.count() / patched.size() * 100,
})

coverage
# Out:
#                                               latest coverage  \
# variable_name
# % of economically inactive student                  84.789392
# % who are economically inactive - aged 16+          98.595944
# % who are economically inactive - aged 16-19        77.379095
# % who are economically inactive - aged 16-24        89.157566
# % who are economically inactive - aged 16-64        98.595944
# % who are economically inactive - aged 20-24        34.243370
# Economic activity rate - aged 16-19                 55.850234
# Economic activity rate - aged 16-64                 98.595944
# Economic activity rate - aged 20-24                 78.627145
# Unemployment rate - aged 16+                        58.658346
# Unemployment rate - aged 16-19                       6.006240
# Unemployment rate - aged 16-24                      16.614665
# Unemployment rate - aged 16-64                      57.020281
# Unemployment rate - aged 20-24                       3.588144
#
#                                               patched coverage
# variable_name
# % of economically inactive student                   97.877358
# % who are economically inactive - aged 16+           98.584906
# % who are economically inactive - aged 16-19         97.720126
# % who are economically inactive - aged 16-24         98.506289
# % who are economically inactive - aged 16-64         98.584906
# % who are economically inactive - aged 20-24         67.610063
# Economic activity rate - aged 16-19                  90.566038
# Economic activity rate - aged 16-64                  98.584906
# Economic activity rate - aged 20-24                  97.641509
# Unemployment rate - aged 16+                         93.553459
# Unemployment rate - aged 16-19                       17.295597
# Unemployment rate - aged 16-24                       42.845912
# Unemployment rate - aged 16-64                       92.688679
# Unemployment rate - aged 20-24                       12.028302

# %%
ax = coverage.plot.barh()
