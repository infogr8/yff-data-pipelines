# %%
from pathlib import Path

import pandas as pd
import petl as etl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
# %matplotlib inline

# %%
ROOT = Path('../..')

SRC_FILE = ROOT / 'data/raw/lfs_by_pcon.csv'

OUT_DIR = ROOT / 'data/processed/labour-market/'
OUT_DIR.mkdir(parents=True, exist_ok=True)

OUT_FILE = OUT_DIR / 'labour_market_by_pcon.csv'
PQ_FILE = OUT_DIR / 'labour_market_by_pcon.parquet'

# %% [markdown]
# Load the latest CSV. This is downloaded by the 'download-from-nomis-api.py' script.

# %%
data = etl.fromcsv(
  SRC_FILE
).convertall(
  lambda x: x.strip()
).convert(
  {
    'DATE': etl.dateparser('%Y-%m'),
    'OBS_VALUE': float
  }
).selecteq(
  'MEASURES_NAME', 'Variable'
).selectin(
  'GEOGRAPHY_TYPE', ['parliamentary constituencies 2010', 'Westminster Parliamentary Constituencies (July 2024)']
).cut(
  'DATE', 'DATE_NAME', 'GEOGRAPHY_CODE', 'GEOGRAPHY_NAME', 'VARIABLE_CODE', 'VARIABLE_NAME', 'OBS_VALUE', 'OBS_STATUS_NAME'
).rename({
  'DATE': 'date',
  'DATE_NAME': 'date_name',
  'GEOGRAPHY_CODE': 'geography_code',
  'GEOGRAPHY_NAME': 'geography_name',
  'VARIABLE_CODE': 'variable_code',
  'VARIABLE_NAME': 'variable_name',
  'OBS_VALUE': 'value',
  'OBS_STATUS_NAME': 'notes'
})

data
# Out:
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | date                       | date_name           | geography_code | geography_name             | variable_code | variable_name                         | value | notes          |
# +============================+=====================+================+============================+===============+=======================================+=======+================+
# | datetime.date(2021, 12, 1) | 'Jan 2021-Dec 2021' | 'E14000530'    | 'Aldershot'                | '18'          | 'Economic activity rate - aged 16-64' |  85.7 | 'Normal Value' |
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2021, 12, 1) | 'Jan 2021-Dec 2021' | 'E14000531'    | 'Aldridge-Brownhills'      | '18'          | 'Economic activity rate - aged 16-64' |  86.4 | 'Normal Value' |
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2021, 12, 1) | 'Jan 2021-Dec 2021' | 'E14000532'    | 'Altrincham and Sale West' | '18'          | 'Economic activity rate - aged 16-64' |  80.0 | 'Normal Value' |
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2021, 12, 1) | 'Jan 2021-Dec 2021' | 'E14000533'    | 'Amber Valley'             | '18'          | 'Economic activity rate - aged 16-64' |  76.4 | 'Normal Value' |
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# | datetime.date(2021, 12, 1) | 'Jan 2021-Dec 2021' | 'E14000534'    | 'Arundel and South Downs'  | '18'          | 'Economic activity rate - aged 16-64' |  83.6 | 'Normal Value' |
# +----------------------------+---------------------+----------------+----------------------------+---------------+---------------------------------------+-------+----------------+
# ...

# %% [markdown]
# Save the file to CSV

# %%
data.tocsv(OUT_FILE)

# %% [markdown]
# Convert to pandas for further processing, and save Parquet file

# %%
frame = data.todataframe()
frame.date = pd.to_datetime(frame.date)
frame.to_parquet(PQ_FILE)

# %% [markdown]
# Check missing data

# %%
def visualise_coverage(data):
    counts = pd.DataFrame({
      'available': data.groupby(['date', 'variable_name']).value.count(),
      'total': data.groupby(['date', 'variable_name']).value.size()
    })
    coverage = pd.Series(
      counts.available / counts.total, name='coverage'
    ).reset_index().pivot(
      index='variable_name', columns='date', values='coverage'
    )
    plt.imshow(coverage, origin='lower', cmap='viridis', interpolation='nearest', aspect='auto')
    plt.grid(None)
    plt.ylabel('Measure')
    plt.yticks(ticks=range(len(coverage.index)), labels=coverage.index)
    plt.xticks(ticks=range(len(coverage.columns)), labels=coverage.columns.to_series().dt.strftime('%b %Y'), rotation=90, horizontalalignment='center')
    return coverage

frame.pipe(visualise_coverage)
# Out:
# date                                          2021-12-01  2022-03-01  \
# variable_name
# % of economically inactive student              0.903276    0.905616
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.865835    0.861154
# % who are economically inactive - aged 16-24    0.926677    0.933697
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.400156    0.381435
# Economic activity rate - aged 16-19             0.646646    0.654446
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.907956    0.901716
# Unemployment rate - aged 16+                    0.765211    0.726989
# Unemployment rate - aged 16-19                  0.075663    0.051482
# Unemployment rate - aged 16-24                  0.221529    0.177067
# Unemployment rate - aged 16-64                  0.753510    0.705928
# Unemployment rate - aged 20-24                  0.058502    0.039002
#
# date                                          2022-06-01  2022-09-01  \
# variable_name
# % of economically inactive student              0.902496    0.884555
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.836973    0.822153
# % who are economically inactive - aged 16-24    0.921997    0.912637
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.358814    0.346334
# Economic activity rate - aged 16-19             0.661466    0.662246
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.878315    0.866615
# Unemployment rate - aged 16+                    0.691888    0.663807
# Unemployment rate - aged 16-19                  0.045242    0.037441
# Unemployment rate - aged 16-24                  0.136505    0.126365
# Unemployment rate - aged 16-64                  0.667707    0.640406
# Unemployment rate - aged 20-24                  0.032761    0.017941
#
# date                                          2022-12-01  2023-03-01  \
# variable_name
# % of economically inactive student              0.865055    0.821373
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.783931    0.740250
# % who are economically inactive - aged 16-24    0.886115    0.865835
# % who are economically inactive - aged 16-64    0.985959    0.985959
# % who are economically inactive - aged 20-24    0.342434    0.329953
# Economic activity rate - aged 16-19             0.608424    0.574103
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.839314    0.805772
# Unemployment rate - aged 16+                    0.627145    0.586583
# Unemployment rate - aged 16-19                  0.041342    0.036661
# Unemployment rate - aged 16-24                  0.113105    0.124025
# Unemployment rate - aged 16-64                  0.592044    0.559282
# Unemployment rate - aged 20-24                  0.019501    0.025741
#
# date                                          2023-06-01  2023-09-01  \
# variable_name
# % of economically inactive student              0.787051    0.735569
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.705148    0.649766
# % who are economically inactive - aged 16-24    0.829953    0.785491
# % who are economically inactive - aged 16-64    0.985959    0.985179
# % who are economically inactive - aged 20-24    0.287832    0.251950
# Economic activity rate - aged 16-19             0.532761    0.471919
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.776911    0.726209
# Unemployment rate - aged 16+                    0.566303    0.498440
# Unemployment rate - aged 16-19                  0.032761    0.024181
# Unemployment rate - aged 16-24                  0.113105    0.096724
# Unemployment rate - aged 16-64                  0.531981    0.468019
# Unemployment rate - aged 20-24                  0.021841    0.013261
#
# date                                          2023-12-01  2024-03-01  \
# variable_name
# % of economically inactive student              0.725429    0.726209
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.624805    0.635725
# % who are economically inactive - aged 16-24    0.770671    0.773011
# % who are economically inactive - aged 16-64    0.984399    0.982839
# % who are economically inactive - aged 20-24    0.222309    0.204368
# Economic activity rate - aged 16-19             0.445398    0.445398
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.693448    0.697348
# Unemployment rate - aged 16+                    0.474259    0.496880
# Unemployment rate - aged 16-19                  0.028861    0.027301
# Unemployment rate - aged 16-24                  0.080343    0.094384
# Unemployment rate - aged 16-64                  0.454758    0.471139
# Unemployment rate - aged 20-24                  0.014041    0.013261
#
# date                                          2024-06-01  2024-09-01  \
# variable_name
# % of economically inactive student              0.762871    0.793292
# % who are economically inactive - aged 16+      0.985959    0.985959
# % who are economically inactive - aged 16-19    0.678627    0.724649
# % who are economically inactive - aged 16-24    0.799532    0.824493
# % who are economically inactive - aged 16-64    0.982839    0.985959
# % who are economically inactive - aged 20-24    0.241810    0.275351
# Economic activity rate - aged 16-19             0.460998    0.494540
# Economic activity rate - aged 16-64             0.985959    0.985959
# Economic activity rate - aged 20-24             0.712168    0.748830
# Unemployment rate - aged 16+                    0.481279    0.512480
# Unemployment rate - aged 16-19                  0.026521    0.031201
# Unemployment rate - aged 16-24                  0.094384    0.120125
# Unemployment rate - aged 16-64                  0.458658    0.490640
# Unemployment rate - aged 20-24                  0.018721    0.021841
#
# date                                          2024-12-01
# variable_name
# % of economically inactive student              0.827613
# % who are economically inactive - aged 16+      0.985959
# % who are economically inactive - aged 16-19    0.750390
# % who are economically inactive - aged 16-24    0.866615
# % who are economically inactive - aged 16-64    0.985179
# % who are economically inactive - aged 20-24    0.307332
# Economic activity rate - aged 16-19             0.542902
# Economic activity rate - aged 16-64             0.985959
# Economic activity rate - aged 20-24             0.772231
# Unemployment rate - aged 16+                    0.568643
# Unemployment rate - aged 16-19                  0.049142
# Unemployment rate - aged 16-24                  0.146646
# Unemployment rate - aged 16-64                  0.540562
# Unemployment rate - aged 20-24                  0.026521

# %% [markdown]
# Get the most recently published data per area, to increase coverage

# %%
def get_latest_available(data):
  # Calculate dates
  failsafe_date = data.date.min() - pd.Timedelta("1 days")
  latest_date = data.date.max()
  # Subset the input data
  test_data = data.loc[:, ['geography_code', 'date', 'variable_name', 'value']]
  # Construct a failsafe (to be used in the event that there is no data available)
  # This will have the same index as the most recent values, which we use below...
  failsafe_data = test_data.loc[test_data.date == latest_date]
  failsafe_data.loc[:, ['date', 'value']] = (failsafe_date, -1)
  # Concatenate the test and failsafe_data
  test_data = pd.concat([ test_data, failsafe_data ]).sort_values('date', ascending=True)
  # Get the indexes for the non-zero values
  indexes = test_data.dropna(subset='value').groupby(['geography_code', 'variable_name'])['date'].idxmax()
  return data.loc[indexes]

latest_available = frame.pipe(get_latest_available)

# %%
latest = frame.loc[frame.date == frame.date.max()].groupby(['variable_name']).value
patched = latest_available.groupby(['variable_name']).value
coverage = pd.DataFrame({
  'latest coverage': latest.count() / latest.size() * 100,
  'patched coverage': patched.count() / patched.size() * 100,
})

coverage
# Out:
#                                               latest coverage  \
# variable_name
# % of economically inactive student                  82.761310
# % who are economically inactive - aged 16+          98.595944
# % who are economically inactive - aged 16-19        75.039002
# % who are economically inactive - aged 16-24        86.661466
# % who are economically inactive - aged 16-64        98.517941
# % who are economically inactive - aged 20-24        30.733229
# Economic activity rate - aged 16-19                 54.290172
# Economic activity rate - aged 16-64                 98.595944
# Economic activity rate - aged 20-24                 77.223089
# Unemployment rate - aged 16+                        56.864275
# Unemployment rate - aged 16-19                       4.914197
# Unemployment rate - aged 16-24                      14.664587
# Unemployment rate - aged 16-64                      54.056162
# Unemployment rate - aged 20-24                       2.652106
#
#                                               patched coverage
# variable_name
# % of economically inactive student                   97.955975
# % who are economically inactive - aged 16+           98.584906
# % who are economically inactive - aged 16-19         97.405660
# % who are economically inactive - aged 16-24         98.506289
# % who are economically inactive - aged 16-64         98.584906
# % who are economically inactive - aged 20-24         68.003145
# Economic activity rate - aged 16-19                  91.194969
# Economic activity rate - aged 16-64                  98.584906
# Economic activity rate - aged 20-24                  98.034591
# Unemployment rate - aged 16+                         94.182390
# Unemployment rate - aged 16-19                       17.688679
# Unemployment rate - aged 16-24                       44.418239
# Unemployment rate - aged 16-64                       93.474843
# Unemployment rate - aged 20-24                       12.578616

# %%
ax = coverage.plot.barh()
